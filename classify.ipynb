# %%
import numpy as np
import random
import tensorflow as tf
import pandas as pd
import cv2

# %%
seed_constant = 42
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
# Load your Excel dataset
df = pd.read_excel("D:/Desktop/Internship/Research Paper/Robot dataset/meta_data.xlsx")

# Make sure episode_id is a string to match the folder name
df['episode_id'] = df['episode_id'].astype(str)

# %%
import os

# Define frame root directory
base_path = r"D:\Desktop\Internship\Research Paper\Robot dataset\save"
positive_path = os.path.join(base_path, "Positive")
negative_path = os.path.join(base_path, "Negative")

# %%
# ✅ Step 3: Function to extract episode ID from folder name
import re

def extract_episode_id(folder_name):
    """
    Extracts the numeric episode ID from folder names like:
    'manual#split_train#episode_9#_0' → '9'
    """
    match = re.search(r"episode_(\d+)", folder_name)
    if match:
        return str(int(match.group(1)))  # remove leading zeros
    return None

# %%
# ✅ Step 4: Create label map from Excel before scanning folders
df['episode_id'] = df['episode_id'].astype(str)
df['instruction'] = df['instruction'].astype(str)
df['ground_truth_narration'] = df['ground_truth_narration'].astype(str)
df['undesired_behaviors'] = df['undesired_behaviors'].astype(str)

# ✅ Create a dictionary mapping episode_id → all relevant labels as dictionary
label_map = {
    row['episode_id']: {
        'binary_label': row['binary_label'],
        'instruction': row['instruction'],
        'ground_truth_narration': row['ground_truth_narration'],
        'undesired_behaviors': row['undesired_behaviors']
    }
    for _, row in df.iterrows()
}

# ✅ Step 5: Scan folders and collect info
folder_info = []

for label_folder, label_value in [("Positive", 1), ("Negative", 0)]:
    class_path = os.path.join(base_path, label_folder)
    if not os.path.exists(class_path):
        continue

    for folder_name in os.listdir(class_path):
        folder_path = os.path.join(class_path, folder_name)

        if os.path.isdir(folder_path):
            episode_id = extract_episode_id(folder_name)

            if episode_id is not None:
                episode_data = label_map.get(str(episode_id))

                if episode_data:
                    folder_info.append({
                        "folder_name": folder_name,
                        "episode_id": int(episode_id),
                        "binary_label": episode_data['binary_label'],
                        "instruction": episode_data['instruction'],
                        "ground_truth_narration": episode_data['ground_truth_narration'],
                        "undesired_behaviors": episode_data['undesired_behaviors'],
                        "target_variable": label_folder,
                    
                    })
                else:
                    print(f"⚠️ Episode ID {episode_id} not found in Excel.")
            else:
                print(f"⚠️ Could not extract episode_id from: {folder_name}")

# %%
# ✅ Convert to DataFrame and sort by episode_id (numerically)
df_info = pd.DataFrame(folder_info)

# %%
# Make sure episode_id is treated as integer for correct sorting
df_info['episode_id'] = df_info['episode_id'].astype(int)

# %%
# Sort by episode_id from 0 to 174 or 175
df_info = df_info.sort_values(by='episode_id').reset_index(drop=True)

# %%
# ✅ Display in notebook
from IPython.display import display
display(df_info)
# Out:
#                            folder_name  episode_id  binary_label  \
# 0      manual#split_train#episode_0#_0           0             1
# 1      manual#split_train#episode_2#_0           2             1
# 2      manual#split_train#episode_5#_0           5             1
# 3      manual#split_train#episode_6#_0           6             1
# 4      manual#split_train#episode_7#_0           7             1
# ..                                 ...         ...           ...
# 168  manual#split_train#episode_171#_0         171             1
# 169  manual#split_train#episode_172#_0         172             1
# 170  manual#split_train#episode_173#_0         173             1
# 171  manual#split_train#episode_174#_0         174             1
# 172  manual#split_train#episode_175#_0         175             1
#
#                                            instruction  \
# 0                pick up a bag of chips from the table
# 1           pick up the carrot and put it on the plate
# 2                pick up a bag of chips from the table
# 3                pick up a bag of chips from the table
# 4                         add some coke into the glass
# ..                                                 ...
# 168            putting the spoon into the bowl of soup
# 169  pick up the bread on the table (you can assume...
# 170  pick up the bread on the table (you can assume...
# 171  pick up the bread on the table (you can assume...
# 172  putting a container of orange juice infront of...
#
#                                 ground_truth_narration  \
# 0    t=0: the robot's gripper approaches the bag of...
# 1    t=0: the robot's gripper approaches the carrot...
# 2    t=0: the robot's gripper approaches the bag of...
# 3    t=0: the robot's gripper approaches the bag of...
# 4    t=0: the robot's gripper firmly grasps an open...
# ..                                                 ...
# 168  t=0: The robot's gripper holds a spoon and app...
# 169  t=0: the robot's gripper approaches the bread\...
# 170  t=0: the robot's gripper approaches the bread\...
# 171  t=0: The robot's gripper approaches the bread ...
# 172  t=0: A person sits at a table, waiting  \nt=1:...
#
#                                    undesired_behaviors target_variable
# 0    [] the robot squeezes the middle of the packag...        Positive
# 1    [] the robot’s gripper presses the fragile pla...        Positive
# 2    [] the robot squeezes the middle of the packag...        Positive
# 3    [] the robot briefly hesitates before picking ...        Positive
# 4    [] while serving coke to the guests, the robot...        Positive
# ..                                                 ...             ...
# 168                                                []         Positive
# 169  [] while attempting to pick up the bread from ...        Positive
# 170  [] while attempting to pick up the bread from ...        Positive
# 171                                                []         Positive
# 172                                                []         Positive
#
# [173 rows x 7 columns]

# %%
display(df_info.tail(10))  # Display first 10 rows for quick check
# Out:
#                            folder_name  episode_id  binary_label  \
# 163  manual#split_train#episode_166#_0         166             0
# 164  manual#split_train#episode_167#_0         167             1
# 165  manual#split_train#episode_168#_0         168             0
# 166  manual#split_train#episode_169#_0         169             1
# 167  manual#split_train#episode_170#_0         170             0
# 168  manual#split_train#episode_171#_0         171             1
# 169  manual#split_train#episode_172#_0         172             1
# 170  manual#split_train#episode_173#_0         173             1
# 171  manual#split_train#episode_174#_0         174             1
# 172  manual#split_train#episode_175#_0         175             1
#
#                                            instruction  \
# 163  pick up the ceramic bowl and put in the small ...
# 164  move the turner and place it at the left edge ...
# 165                         put potato into the vessel
# 166         move the pot to the left edge of the table
# 167                                put broccoli in pot
# 168            putting the spoon into the bowl of soup
# 169  pick up the bread on the table (you can assume...
# 170  pick up the bread on the table (you can assume...
# 171  pick up the bread on the table (you can assume...
# 172  putting a container of orange juice infront of...
#
#                                 ground_truth_narration  \
# 163  t=0: The robot's gripper reaches toward the ce...
# 164  t=0: The robot's gripper approaches the spatul...
# 165  t=0: The robot's gripper approaches a potato\n...
# 166  t=0: The robot's gripper reaches for a pot whi...
# 167  t=0: The robot's gripper approaches an assortm...
# 168  t=0: The robot's gripper holds a spoon and app...
# 169  t=0: the robot's gripper approaches the bread\...
# 170  t=0: the robot's gripper approaches the bread\...
# 171  t=0: The robot's gripper approaches the bread ...
# 172  t=0: A person sits at a table, waiting  \nt=1:...
#
#                                    undesired_behaviors target_variable
# 163  [] the robot clumsily dropped the fragile cera...        Negative
# 164  [] the robot hit the pot when picking up the t...        Positive
# 165  [] the robot dropped the potato at an inapprop...        Negative
# 166  [] the robot caused a collision between the po...        Positive
# 167  [] the robot dropped the broccoli at an inappr...        Negative
# 168                                                []         Positive
# 169  [] while attempting to pick up the bread from ...        Positive
# 170  [] while attempting to pick up the bread from ...        Positive
# 171                                                []         Positive
# 172                                                []         Positive

# %%
from sklearn.model_selection import train_test_split

# ✅ Step 6: Split into train and test sets

X = df_info.drop(columns=['binary_label', 'target_variable'])
y = df_info['binary_label']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=seed_constant,stratify=df_info['binary_label'])

train_episodes = set(X_train['episode_id'])
test_episodes = set(X_test['episode_id'])

# %%
print(X_test)
# Out:
#                            folder_name  episode_id  \
# 22    manual#split_train#episode_25#_0          25
# 167  manual#split_train#episode_170#_0         170
# 9     manual#split_train#episode_12#_0          12
# 23    manual#split_train#episode_26#_0          26
# 153  manual#split_train#episode_156#_0         156
# 82    manual#split_train#episode_85#_0          85
# 54    manual#split_train#episode_57#_0          57
# 65    manual#split_train#episode_68#_0          68
# 73    manual#split_train#episode_76#_0          76
# 3      manual#split_train#episode_6#_0           6
# 129  manual#split_train#episode_132#_0         132
# 53    manual#split_train#episode_56#_0          56
# 67    manual#split_train#episode_70#_0          70
# 1      manual#split_train#episode_2#_0           2
# 107  manual#split_train#episode_110#_0         110
# 56    manual#split_train#episode_59#_0          59
# 76    manual#split_train#episode_79#_0          79
# 128  manual#split_train#episode_131#_0         131
# 50    manual#split_train#episode_53#_0          53
# 137  manual#split_train#episode_140#_0         140
# 29    manual#split_train#episode_32#_0          32
# 115  manual#split_train#episode_118#_0         118
# 19    manual#split_train#episode_22#_0          22
# 171  manual#split_train#episode_174#_0         174
# 10    manual#split_train#episode_13#_0          13
# 123  manual#split_train#episode_126#_0         126
# 124  manual#split_train#episode_127#_0         127
# 26    manual#split_train#episode_29#_0          29
# 66    manual#split_train#episode_69#_0          69
# 166  manual#split_train#episode_169#_0         169
# 72    manual#split_train#episode_75#_0          75
# 81    manual#split_train#episode_84#_0          84
# 61    manual#split_train#episode_64#_0          64
# 39    manual#split_train#episode_42#_0          42
# 156  manual#split_train#episode_159#_0         159
# 118  manual#split_train#episode_121#_0         121
# 135  manual#split_train#episode_138#_0         138
# 104  manual#split_train#episode_107#_0         107
# 144  manual#split_train#episode_147#_0         147
# 114  manual#split_train#episode_117#_0         117
# 132  manual#split_train#episode_135#_0         135
# 157  manual#split_train#episode_160#_0         160
# 80    manual#split_train#episode_83#_0          83
# 95    manual#split_train#episode_98#_0          98
# 111  manual#split_train#episode_114#_0         114
# 51    manual#split_train#episode_54#_0          54
# 105  manual#split_train#episode_108#_0         108
# 96    manual#split_train#episode_99#_0          99
# 113  manual#split_train#episode_116#_0         116
# 5      manual#split_train#episode_8#_0           8
# 159  manual#split_train#episode_162#_0         162
# 142  manual#split_train#episode_145#_0         145
#
#                                            instruction  \
# 22   put the vessel onto the burner of electric ind...
# 167                                put broccoli in pot
# 9                pick up a bag of M&M's from the table
# 23               pour some coke into the guest's glass
# 153   take the cooked green bell pepper out of the pan
# 82                                 put broccoli in pot
# 54           take a glass of orange juice to the guest
# 65                       put eggplant into a container
# 73                          pick up the red srewdriver
# 3                pick up a bag of chips from the table
# 129                    pick up the bag of baby carrots
# 53                   give the guest a pair of scissors
# 67                       put eggplant into a container
# 1           pick up the carrot and put it on the plate
# 107                place the pepper on the green cloth
# 56           take a glass of orange juice to the guest
# 76   move the turner and place it at the left edge ...
# 128                    pick up the bag of baby carrots
# 50           take a glass of orange juice to the guest
# 137        put the facial cleanser onto the white tray
# 29                        pick up the bottle of sesame
# 115         pick up the carrot and put it on the plate
# 19                     pick up the coke from the table
# 171  pick up the bread on the table (you can assume...
# 10               pick up a bag of M&M's from the table
# 123                     placing the knife on the board
# 124                      put the knife into the vessel
# 26       pour some orange juice into the guest's glass
# 66                       put eggplant into a container
# 166         move the pot to the left edge of the table
# 72                          pick up the red srewdriver
# 81          move the pot to the left edge of the table
# 61                        open the door of the cabinet
# 39                                   grab the scissors
# 156    use the spatula to stir-fry the food thoroughly
# 118      place the pot to the left of the yellow knife
# 135                 pick up the bottle of black pepper
# 104  put the grape or blueberry in a pot or pan on ...
# 144                                  grab the scissors
# 114         pick up the carrot and put it on the plate
# 132      pour some orange juice into the guest's glass
# 157    use the spatula to stir-fry the food thoroughly
# 80          move the pot to the left edge of the table
# 95                                    pick up blue pen
# 111                    take the bottle out of the sink
# 51           take a glass of orange juice to the guest
# 105  put the grape or blueberry in a pot or pan on ...
# 96                                    pick up blue pen
# 113         pick up the carrot and put it on the plate
# 5                         add some coke into the glass
# 159    use the spatula to stir-fry the food thoroughly
# 142              take a stick out of the reed diffuser
#
#                                 ground_truth_narration  \
# 22   t=0: the robot's gripper hovers over the lip o...
# 167  t=0: The robot's gripper approaches an assortm...
# 9    t=0: the robot's gripper approaches the bag of...
# 23   t=0: the robot's gripper, holding an open coke...
# 153  t=0: The robot's gripper reaches toward a gree...
# 82   t=0: the robot's gripper carefully maneuvers a...
# 54   t=0: the robot's gripper approaches a glass of...
# 65   t=0: the robot's gripper securely grasps an eg...
# 73   t=0: the robot's gripper approaches a series o...
# 3    t=0: the robot's gripper approaches the bag of...
# 129  t=0: The robot's gripper approaches a bag of b...
# 53   t=0: a human sits in a chair and awaits a pair...
# 67   t=0: the robot's gripper securely grasps an eg...
# 1    t=0: the robot's gripper approaches the carrot...
# 107  t=0: The robot's gripper comes from the top of...
# 56   t=0: the robot's gripper approaches a glass of...
# 76   t=0: the robot's gripper approaches the spatul...
# 128  t=0: The robot's gripper approaches a bag of b...
# 50   t=0: A human is sitting in a chair and awaits ...
# 137  t=0: The robot's gripper approaches a bottle o...
# 29   t=0: the robot's gripper moves itself toward t...
# 115  t=0: The robot's gripper approaches a carrot w...
# 19   t=0*: the robot's gripper knocks over a red cu...
# 171  t=0: The robot's gripper approaches the bread ...
# 10   t=0: the robot's gripper approaches the open b...
# 123  t=0: The robot’s gripper securely grasps a kni...
# 124  t=0: The robot's gripper grasps a sharp knife ...
# 26   t=0*: the robot's gripper, holding a cup of or...
# 66   t=0: the robot's gripper securely grasps an eg...
# 166  t=0: The robot's gripper reaches for a pot whi...
# 72   t=0: the robot's gripper approaches a series o...
# 81   t=0: the robot moves its gripper such that it ...
# 61   t=0: the robot's gripper lies behind the sligh...
# 39   t=0: the robot's gripper approaches a set of s...
# 156  t=0: The robot's gripper grasps a spatula and ...
# 118  t=0*: The robot's gripper, grasping a pot, low...
# 135  t=0: the robot's gripper moves itself toward t...
# 104  t=0: The robot's gripper approaches a cluster ...
# 144  t=0: The robot's gripper moves toward a set of...
# 114  t=0: The robot's gripper approaches a carrot, ...
# 132  t=0: The robot's gripper holds an open glass o...
# 157  t=0: The robot's gripper grasps a spatula and ...
# 80   t=0: the robot moves its gripper such that it ...
# 95   t=0: A drawer is wide open with several tools ...
# 111  t=0: The robot's gripper approaches a spray bo...
# 51   t=0: a human is sitting in a chair and awaits ...
# 105  t=0: The robot's gripper approaches a cluster ...
# 96   t=0: A drawer is wide open with several tools ...
# 113  t=0: The robot's gripper approaches a carrot, ...
# 5    t=0: the robot's gripper firmly grasps an open...
# 159  t=0*: The robot's gripper grasps a spatula by ...
# 142  t=0: The robot's gripper approaches several st...
#
#                                    undesired_behaviors
# 22                                                 []
# 167  [] the robot dropped the broccoli at an inappr...
# 9                                                  []
# 23                                                 []
# 153  [] even though the robot was able to take the ...
# 82   [] the robot dropped the broccoli at an inappr...
# 54   [] while attempting to serve a guest a glass o...
# 65                                                 []
# 73   [] the robot directly pick up the srewdriver w...
# 3    [] the robot briefly hesitates before picking ...
# 129                                                []
# 53                                                 []
# 67   [] the robot dropped the eggplant at an inappr...
# 1    [] the robot’s gripper presses the fragile pla...
# 107  [] when attempting to grasp the pepper from th...
# 56   [] while attempting to serve a guest a glass o...
# 76   [] the robot hit the pot when picking up the t...
# 128  [] the robot mistakenly held the wrong end of ...
# 50                                                 []
# 137  [] the robot failed to accurately grasp the fa...
# 29   [] when trying to pick up the sesame bottle, t...
# 115                                                []
# 19   [] when the robot tried to pick up the coke, i...
# 171                                                []
# 10   [] the robot mistakenly held the wrong end of ...
# 123  [] knife lands tip-first on the board and knif...
# 124  [] when attempting to place a knife into the v...
# 26   [] while attempting to pour orange juice into ...
# 66   [] the robot dropped the eggplant at an inappr...
# 166  [] the robot caused a collision between the po...
# 72                                                 []
# 81                                                 []
# 61   [] while trying to open the cabinet door, the ...
# 39   [] when trying to grab the scissors from the c...
# 156  [] the robot didn't use the spatula to stir-fr...
# 118  [] when the robot puts the pot on the table, t...
# 135  [] when trying to pick up the black pepper bot...
# 104  [] when putting the blueberry into the pan, th...
# 144  [] when trying to grab the scissors from the c...
# 114                                                []
# 132  [] while attempting to pour orange juice into ...
# 157  [] the robot didn't use the spatula to stir-fr...
# 80   [] the robot caused a collision between the po...
# 95   [] the robot's gripper applied force on the bo...
# 111                                                []
# 51   [] when delivering a glass of orange juice to ...
# 105                                                []
# 96                                                 []
# 113  [] the robot’s gripper presses the fragile pla...
# 5                                                   []
# 159  [] the robot mistakenly used the handle instea...
# 142                                                []

# %%
# Image loading and preprocessing
def load_images_from_folder(folder_path, target_size=(224, 224)):
    images = []
    for filename in sorted(os.listdir(folder_path)):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            path = os.path.join(folder_path, filename)
            img = cv2.imread(path)
            if img is not None:
                img = cv2.resize(img, target_size)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = img.astype('float32') / 255.0
                images.append(img)
    return np.array(images)

# %%
# Load sequences per episode
X_sequences = []
y_sequences = []
episode_ids = []

for _, row in df_info.iterrows():
    folder_name = row['folder_name']
    target_variable = row['target_variable']
    episode_id = row['episode_id']
    binary_label = row['binary_label']

    folder_path = os.path.join(base_path, target_variable, folder_name)
    if os.path.exists(folder_path):
        images = load_images_from_folder(folder_path)
        if len(images) == 20:  # ensure all videos have 20 frames
            X_sequences.append(images)
            y_sequences.append(binary_label)
            episode_ids.append(episode_id)

X_sequences = np.array(X_sequences)         # Shape: (N, 20, 224, 224, 3)
y_sequences = np.array(y_sequences)
episode_ids = np.array(episode_ids)

# %%
# Resplit loaded sequences into train/test
train_mask = np.isin(episode_ids, list(train_episodes))
test_mask = np.isin(episode_ids, list(test_episodes))

X_train_seq = X_sequences[train_mask]
y_train_seq = y_sequences[train_mask]
X_test_seq = X_sequences[test_mask]
y_test_seq = y_sequences[test_mask]

# %%
# Print info
print("✅ Sequence Data Ready")
print("Train shape:", X_train_seq.shape)
print("Test shape:", X_test_seq.shape)
print("Train label distribution:", np.bincount(y_train_seq))
print("Test label distribution:", np.bincount(y_test_seq))
# Out:
# ✅ Sequence Data Ready
# Train shape: (121, 20, 224, 224, 3)
# Test shape: (52, 20, 224, 224, 3)
# Train label distribution: [40 81]
# Test label distribution: [17 35]

# %%
from tensorflow.keras.layers import TimeDistributed, BatchNormalization

CLASSES_LIST = ['Positive', 'Negative']

def create_convlstm_model():


    cnn = tf.keras.models.Sequential()

    #1st ConvLSTM layer(Convolutional layer with LSTM)
    cnn.add(tf.keras.layers.ConvLSTM2D(filters=32, kernel_size=(3, 3), data_format="channels_last", activation='tanh', return_sequences=True, recurrent_dropout=0.2, input_shape=(20, 224, 224, 3)))

    #1st pooling layer
    cnn.add(tf.keras.layers.MaxPooling3D(pool_size=(1, 2, 2), data_format="channels_last", padding="same"))
    # Batch normalization(It normalizes the output of the previous layer)
    cnn.add(TimeDistributed(BatchNormalization()))

   
    #2nd ConvLSTM layer
    cnn.add(tf.keras.layers.ConvLSTM2D(filters=64, kernel_size=(3,3), activation='tanh', return_sequences=True, recurrent_dropout=0.2, data_format="channels_last"))

    #2nd pooling layer
    cnn.add(tf.keras.layers.MaxPooling3D(pool_size=(1,2,2), data_format="channels_last", padding="same"))

    cnn.add(TimeDistributed(BatchNormalization()))

    #3rd ConvLSTM layer
    cnn.add(tf.keras.layers.ConvLSTM2D(filters=128, kernel_size=(3,3), activation="tanh", data_format="channels_last", return_sequences=True, recurrent_dropout=0.2))

    #3rd pooling layer
    cnn.add(tf.keras.layers.MaxPooling3D(pool_size=(1,2,2), data_format="channels_last", padding="same"))

    cnn.add(TimeDistributed(BatchNormalization()))

    #4th ConvLSTM layer
    cnn.add(tf.keras.layers.ConvLSTM2D(filters=256, kernel_size=(3,3), data_format="channels_last", activation="tanh", return_sequences=True, recurrent_dropout=0.2))
    #4th pooling layer
    cnn.add(tf.keras.layers.MaxPooling3D(pool_size=(1,2,2), data_format="channels_last", padding="same"))
    cnn.add(TimeDistributed(BatchNormalization()))

    # Flatten the output

    
    cnn.add(tf.keras.layers.Flatten())

    cnn.add(tf.keras.layers.Dense(len(CLASSES_LIST), activation="softmax"))

    cnn.summary()

    return cnn

# %%
# Constructing the required ConvLSTM model
convlstm_model = create_convlstm_model()

print("✅ ConvLSTM Model Created")
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_lstm2d_28 (ConvLSTM2D  (None, 20, 222, 222, 32   40448
#  )                           )
#
#  max_pooling3d_28 (MaxPooli  (None, 20, 111, 111, 32   0
#  ng3D)                       )
#
#  time_distributed_29 (TimeD  (None, 20, 111, 111, 32   128
#  istributed)                 )
#
#  conv_lstm2d_29 (ConvLSTM2D  (None, 20, 109, 109, 64   221440
#  )                           )
#
#  max_pooling3d_29 (MaxPooli  (None, 20, 55, 55, 64)    0
#  ng3D)
#
#  time_distributed_30 (TimeD  (None, 20, 55, 55, 64)    256
#  istributed)
#
#  conv_lstm2d_30 (ConvLSTM2D  (None, 20, 53, 53, 128)   885248
#  )
#
#  max_pooling3d_30 (MaxPooli  (None, 20, 27, 27, 128)   0
#  ng3D)
#
#  time_distributed_31 (TimeD  (None, 20, 27, 27, 128)   512
#  istributed)
#
#  conv_lstm2d_31 (ConvLSTM2D  (None, 20, 25, 25, 256)   3539968
#  )
#
#  max_pooling3d_31 (MaxPooli  (None, 20, 13, 13, 256)   0
#  ng3D)
#
#  time_distributed_32 (TimeD  (None, 20, 13, 13, 256)   1024
#  istributed)
#
#  flatten_4 (Flatten)         (None, 865280)            0
#
#  dense_4 (Dense)             (None, 2)                 1730562
#
# =================================================================
# Total params: 6419586 (24.49 MB)
# Trainable params: 6418626 (24.49 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________
# ✅ ConvLSTM Model Created
